# %% [markdown]
# # Common Dataset DVC Pipeline — Google Drive Push Ready
#
# DVC Remote: `gdrive://1nVaOpihiS5mKL0eJwxj-D8-1WKA17PAJ`
#
# `python run_pipeline.py` executes `dvc repro` and `dvc push`.

# %%
# !pwd
# !ls -la

# %%
# !pip install -q -r requirements.txt

# %%
# First run may request Google OAuth authentication.
# !python run_pipeline.py

# %%
import pandas as pd

train_df = pd.read_csv('data/splits/train.csv')
valid_df = pd.read_csv('data/splits/valid.csv')
test_df = pd.read_csv('data/splits/test.csv')

total = len(train_df) + len(valid_df) + len(test_df)
print(f'Train : {len(train_df):5d} ({len(train_df) / total:.2%})')
print(f'Valid : {len(valid_df):5d} ({len(valid_df) / total:.2%})')
print(f'Test  : {len(test_df):5d} ({len(test_df) / total:.2%})')
